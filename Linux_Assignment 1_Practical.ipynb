# %% [markdown]
# **Linux Assignment Question and Answers **

# %% [markdown]
# Q4. How do you create a user account account ?
# -> we can create using user account using below command
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q5. What is 'grep' command used for in linux?
# ->
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q6. Step1: Create user p1
#     Step2: He should be part of 3 groups g1,g2,g3
#     Step3: whenever he create a file automatically in th group section of file grp g1 should come
#
# ->  ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q7. Step1: create  directory /temp/bg as root user and create files inside it.
#
# Step2: "abhi" should be the owner of the directory. he should be able to create files and delete files inside the directory and also be able to add content to all files inside the diretory.
#
# -> ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q8. You suspect that a particular process is consuming excessive CPU resources on your Linux server. How would you identify and terminate this process?
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
